# %% [markdown]
# # Intro to Data Science with Pokemon
# ***

# %% [markdown]
# ### Arrays

# %%
food = ["Ham", "Cheese", "Bread", "Mayo", "Lettuce", "Tomato"]

# %%
print(food)
# Out:
# ['Ham', 'Cheese', 'Bread', 'Mayo', 'Lettuce,Tomato']

# %%
print(food[2])
# Out:
# Bread

# %%
sliced_food_list = food[0:4]

# %%
print(sliced_food_list)
# Out:
# ['Ham', 'Cheese', 'Bread']

# %% [markdown]
# ### Import Libraries
# ***

# %%
import pandas as pd
import numpy as py
import seaborn as sb

# %%
print("PANDAS version" + pd.__version__)
print("numpy version" + py.__version__)
print("Seaborn version" + sb.__version__)
# Out:
# PANDAS version2.2.3
# numpy version2.1.1
# Seaborn version0.13.2

# %% [markdown]
# ### Loading Data
# ***

# %%
df = pd.read_csv('pokemon.csv')

# %% [markdown]
# ### Displaying Full Data Frame
# ***

# %%
#pd. set_option('display.max_rows', Name)

# %%
df.head(50)
# Out:
#      Per   Nat     Pokemon   HP  Atk  Def  SpA  SpD  Spe  Total  ... Catch  \
# 0    1.0   1.0   Bulbasaur   45   49   49   65   65   45    318  ...    45
# 1    2.0   2.0     Ivysaur   60   62   63   80   80   60    405  ...    45
# 2    3.0   3.0    Venusaur   80   82   83  100  100   80    525  ...    45
# 3    4.0   4.0  Charmander   39   52   43   60   50   65    309  ...    45
# 4    5.0   5.0  Charmeleon   58   64   58   80   65   80    405  ...    45
# 5    6.0   6.0   Charizard   78   84   78  109   85  100    534  ...    45
# 6    7.0   7.0    Squirtle   44   48   65   60   54   43    314  ...    45
# 7    8.0   8.0   Wartortle   59   63   80   65   80   58    405  ...    45
# 8    9.0   9.0   Blastoise   79   83  100   85  105   78    530  ...    45
# 9   10.0  10.0    Caterpie   45   30   35   20   20   45    195  ...   255
# 10  11.0  11.0     Metapod   50   20   55   25   25   30    205  ...   120
# ...

# %% [markdown]
# ### Accessing Columns
# ***

# %%
df.Pokemon
# Out:
# 0         Bulbasaur
# 1           Ivysaur
# 2          Venusaur
# 3        Charmander
# 4        Charmeleon
#            ...
# 658          Kyurem
# 659          Keldeo
# 660    Meloetta (A)
# 661    Meloetta (P)
# 662        Genesect
# Name: Pokemon, Length: 663, dtype: object

# %%
df.Pokemon[0]
# Out:
# 'Bulbasaur'

# %%
df.Pokemon[0:3]
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Pokemon, dtype: object

# %%
 pokemon_column[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pokemon_column[0]
#
# NameError: name 'pokemon_column' is not defined
